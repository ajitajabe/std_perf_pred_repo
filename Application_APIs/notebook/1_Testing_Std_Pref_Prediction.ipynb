# %% [markdown]
# # Model Testing

# %%
import pandas as pd
import numpy as np
import pickle 
import json
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Load Data

# %%
with open ("Std_Perf_Pred.pkl","rb") as f:
    Std_Per_Pred_model=pickle.load(f)
Std_Per_Pred_model
# Out:
# LinearRegression()

# %%
with open ("Std_Perf_Pred_Columns_data.json","r") as f:
    Columns_data=json.load(f)
Columns_data
# Out:
# {'Gender': {'Male': 1, 'Female': 0},
#  'ParentalSupport': {'High': 2, 'Medium': 1, 'Low': 0}}

# %%
features_name=Std_Per_Pred_model.feature_names_in_
features_name
# Out:
# array(['Gender', 'AttendanceRate', 'StudyHoursPerWeek', 'PreviousGrade',
#        'ExtracurricularActivities', 'ParentalSupport'], dtype=object)

# %%
feature_count=Std_Per_Pred_model.n_features_in_
feature_count
# Out:
# 6

# %% [markdown]
# ## Testing Model

# %%
Gender= "Male"
AttendanceRate=85
StudyHoursPerWeek=5
PreviousGrade=78
ExtracurricularActivities=2
ParentalSupport="High"
Gender=Columns_data["Gender"][Gender]
ParentalSupport=Columns_data["ParentalSupport"][ParentalSupport]

# %%
AttendanceRate=np.sqrt(AttendanceRate)
AttendanceRate
# Out:
# 9.219544457292887

# %%
test_array=np.zeros((1,feature_count))
test_array[0,0]
# Out:
# 0.0

# %%
test_array=np.zeros((1,feature_count))
test_array[0,0]=Gender
test_array[0,1]=AttendanceRate
test_array[0,2]=StudyHoursPerWeek
test_array[0,3]=PreviousGrade
test_array[0,4]=ExtracurricularActivities
test_array[0,5]=ParentalSupport
test_array
# Out:
# array([[ 1.        ,  9.21954446,  5.        , 78.        ,  2.        ,
#          2.        ]])

# %%
def get_std_perf_pre(Gender, AttendanceRate,StudyHoursPerWeek,PreviousGrade,ExtracurricularActivities,ParentalSupport):

    Gender=Columns_data["Gender"][Gender]
    AttendanceRate=np.sqrt(AttendanceRate)
    ParentalSupport=Columns_data["ParentalSupport"][ParentalSupport]
    test_array=np.zeros((1,feature_count))
    test_array[0,0]=Gender
    test_array[0,1]=AttendanceRate
    test_array[0,2]=StudyHoursPerWeek
    test_array[0,3]=PreviousGrade
    test_array[0,4]=ExtracurricularActivities
    test_array[0,5]=ParentalSupport
    Std_pred_per=Std_Per_Pred_model.predict(test_array)[0]
    return Std_pred_per

# %%
Gender= "Female"
AttendanceRate=88
StudyHoursPerWeek=21
PreviousGrade=85
ExtracurricularActivities=2
ParentalSupport="High"
get_std_perf_pre(Gender, AttendanceRate,StudyHoursPerWeek,PreviousGrade,ExtracurricularActivities,ParentalSupport)
# Out:
# 87.37075133332758
